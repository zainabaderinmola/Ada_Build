# %%
import random

def choose_rps():
    '''
    Function allows to randomly choose player choice
    of rock, paper or scissors
    '''
    # r = random.randint(0, 2)  # retuns num 0 - 2 randomly
    for i in range(3):
        r = random.randint(0,2)
        if r == 0:
            return 'Rock'
        elif r == 1:
            return 'Scissors'
        else:
            return 'Paper'
        
choose_rps()
# Out:
# 'Scissors'

# %%
# Rock Paper Scissors altered from function
# to list

import random

def choose_rps():
    '''
    Function allows to randomly choose player choice
    of rock, paper or scissors
    '''
    # r = random.randint(0, 2)  # retuns num 0 - 2 randomly
    for i in range(3):
        r = random.randint(0,2)
        if r == 0:
            return 'Rock'
        elif r == 1:
            return 'Scissors'
        else:
            return 'Paper'

def rps(player_1, player_2):
    '''
    input: the player could be rock, paper or scissors.
    output: it returns
    '''
    if player_1 == player_2 == 'Rock' or player_1 == player_2 == 'Paper' or\
        player_1 == player_2 == 'Scissors':
        print(f"It's a tie!")
        print('------')
    
    elif player_1 == 'Paper' and player_2 == 'Rock' or player_1 == 'Scissors'\
    and player_2 == 'Paper' or player_1 == 'Rock' and\
    player_2 == 'Scissors':
        print('Player 1 wins!')

    else:
        print('Player 2 wins!')

def play_again():
    r = random.randint(0, 1)
    
play = True

print("Welcome to Rock, Paper, Scissors!\n")
while play == True:
  player1 = choose_rps()
  player2 = choose_rps()

  print("Player 1 chose", player1, ".")
  print("Player 2 chose", player2, ".")

  rps(player1, player2)

  print(" ")

  play = play_again()

print("Thank you for playing!")
# Out:
# Welcome to Rock, Paper, Scissors!
#
# Player 1 chose Paper .
# Player 2 chose Rock .
# Player 1 wins!
#
# Thank you for playing!

# %%
import random

def choose_rps():
  for num in range(3):
    r = random.randint(0,2) #returns random number 0 to 2
    
    if r == 0:
        return "rock" # 0 = rock
    elif r == 1:
        return "scissors" # 1 = scissors
    else:
        return "paper" # 2 = paper

def rps_function(player1, player2):
  # tie
  if player1 == player2:
    print("It's a tie!")
  # player1 = scissors
  elif player1 == "scissors":
    if player2 == "rock":
      print ("Player 2 won!")
    else:
      print("Player 1 won!")
    # player1 = rock
  elif player1 == "rock":
    if player2 == "scissors":
      print ("Player 1 won!")
    else:
      print("Player 2 won!")
  # player1 = paper
  else:
    if player2 == "scissors":
      print ("Player 2 won!")
    else:
      print("Player 1 won!")
       

def play_again():
  r = random.randint(0,1)
  if r == 0:
    return True
  else:
    return False

play = True

print("Welcome to Rock, Paper, Scissors!\n")
while play == True:
  player1 = choose_rps()
  player2 = choose_rps()

  print("Player 1 chose", player1, ".")
  print("Player 2 chose", player2, ".")

  rps_function(player1, player2)

  print(" ")

  play = play_again()

print("Thank you for playing!")
# Out:
# Welcome to Rock, Paper, Scissors!
#
# Player 1 chose rock .
# Player 2 chose rock .
# It's a tie!
#
# Player 1 chose rock .
# Player 2 chose scissors .
# Player 1 won!
#
# Player 1 chose scissors .
# Player 2 chose scissors .
# It's a tie!
#
# Player 1 chose scissors .
# Player 2 chose scissors .
# It's a tie!
#
# Thank you for playing!

# %%
import random, time

def choose_rps():
    '''
    Function allows to randomly choose player choice
    of rock, paper or scissors
    '''
    # r = random.randint(0, 2)  # retuns num 0 - 2 randomly
    for i in range(3):
        r = random.randint(0,2)
        if r == 0:
            return 'Rock'
        elif r == 1:
            return 'Scissors'
        else:
            return 'Paper'
    
def play_again():
    r = random.randint(0, 1)
    return r

    
def rps():
    '''
    input: each player could be rock, player or scissors
    output: once the code is run, the return statement should be "it's
    a tie" or "Player 1 won" or "Player 2 won"
    '''
    # Outcome of the game
    result_1 = 'It\'s a tie'
    result_2 = 'Player 2 wins'
    result_3 = 'Player 1 wins'

    play = True
    while play:
        # Player choice
        print("player 1 chooses: ")
        time.sleep(1)
        player_1 = choose_rps()
        print(player_1)
        time.sleep(2)
        print("player 2 chooses: ")
        player_2 = choose_rps()
        print(player_2)

        # When the result is a tie
        if player_1 == player_2 == 'Rock' or player_1 == player_2 == 'Paper' or\
        player_1 == player_2 == 'Scissors':
            print(f"{result_1}\n")
            print('------')
        
        # When Player 2 wins
        elif player_1 == 'Rock' and player_2 == 'Paper':
            print(f"{result_2}\n")
            print('------')

        elif player_1 == 'Paper' and player_2 == 'Scissors':
            print(f"{result_2}\n")
            print('------')

        elif player_1 == 'Scissors' and player_2 == 'Rock':
            print(f"{result_2}\n")
            print('------')

        # When Player 1 wins
        else:
            print(f"{result_3}\n")
            print('----------')
        
        play = play_again()
        # Player choice
        # print("player 1 chooses: ")
        # time.sleep(1)
        # player_1 = choose_rps()
        # print(player_1)
        # time.sleep(2)
        # print("player 2 chooses: ")
        # player_2 = choose_rps()
        # print(player_2)

rps()

print('++++++++++++++++++++++')
print("Thank you for playing!")
print("Game Over!")
# Out:
# player 1 chooses:
# Rock
# player 2 chooses:
# Scissors
# Player 1 wins
#
# ----------
# player 1 chooses:
# Rock
# player 2 chooses:
# Paper
# Player 2 wins
#
# ------
# player 1 chooses:
# Rock
# player 2 chooses:
# Rock
# It's a tie
#
# ------
# ++++++++++++++++++++++
# Thank you for playing!
# Game Over!
